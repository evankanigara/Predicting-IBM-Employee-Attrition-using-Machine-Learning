# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_ibm = pd.read_csv('ibm1.csv')
df_ibm
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely     1102.0                   Sales
# 1      49        No  Travel_Frequently      279.0  Research & Development
# 2      37       Yes      Travel_Rarely     1373.0  Research & Development
# 3      33        No  Travel_Frequently     1392.0  Research & Development
# 4      27        No      Travel_Rarely      591.0  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently      884.0  Research & Development
# 1466   39        No      Travel_Rarely      613.0  Research & Development
# 1467   27        No      Travel_Rarely      155.0  Research & Development
# 1468   49        No  Travel_Frequently     1023.0                   Sales
# 1469   34        No      Travel_Rarely      628.0  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df1=df_ibm.copy()

# %%
df1
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
plt.figure(figsize=(10,5))
plt.pie(df1['Attrition'].value_counts(), labels=['No','Yes'], autopct='%.2f%%')
plt.show()

# %%
def report(df):
    col = []
    d_type = []
    uniques = []
    n_uniques = []
    
    for i in df.columns:
        col.append(i)
        d_type.append(df[i].dtypes)
        uniques.append(df[i].unique()[:5])
        n_uniques.append(df[i].nunique())
    
    return pd.DataFrame({'Column': col, 'd_type': d_type, 'unique_sample': uniques, 'n_uniques': n_uniques})

# %%
report(df1)
# Out:
#                       Column  d_type  \
# 0                        Age   int64
# 1                  Attrition  object
# 2             BusinessTravel  object
# 3                  DailyRate   int64
# 4                 Department  object
# 5           DistanceFromHome   int64
# 6                  Education   int64
# 7             EducationField  object
# 8              EmployeeCount   int64
# 9             EmployeeNumber   int64
# 10   EnvironmentSatisfaction   int64
# 11                    Gender  object
# 12                HourlyRate   int64
# 13            JobInvolvement   int64
# 14                  JobLevel   int64
# 15                   JobRole  object
# 16           JobSatisfaction   int64
# 17             MaritalStatus  object
# 18             MonthlyIncome   int64
# 19               MonthlyRate   int64
# 20        NumCompaniesWorked   int64
# 21                    Over18  object
# 22                  OverTime  object
# 23         PercentSalaryHike   int64
# ...

# %%
df1['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
print(df1['BusinessTravel'].value_counts())
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
print(df1['Department'].value_counts())
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
ax = sns.boxplot(x=df1["DailyRate"])

# %%
sns.displot(df1, x="DistanceFromHome")

# %%
print(df1['Education'].value_counts())
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %%
print(df1['EducationField'].value_counts())
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
print(df1['EnvironmentSatisfaction'].value_counts())
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
print(df1['Gender'].value_counts())
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
ax = sns.boxplot(x=df1["HourlyRate"])

# %% [markdown]
# ## Mencari Korelasi

# %%
print("Bayaran per hari",df1["DailyRate"][0])
print("Bayaran per jam",df1["HourlyRate"][0])
print("1102/24=",df1["DailyRate"][0]/df1["HourlyRate"][0])
# Out:
# Bayaran per hari 1102
# Bayaran per jam 94
# 1102/24= 11.72340425531915

# %%
print("Bayaran per hari",df1["DailyRate"][1])
print("Bayaran per jam",df1["HourlyRate"][1])
print("1102/24=",df1["DailyRate"][1]/df1["HourlyRate"][1])
# Out:
# Bayaran per hari 279
# Bayaran per jam 61
# 1102/24= 4.573770491803279

# %%
df1[['DailyRate','HourlyRate','MonthlyRate']]
# Out:
#       DailyRate  HourlyRate  MonthlyRate
# 0          1102          94        19479
# 1           279          61        24907
# 2          1373          92         2396
# 3          1392          56        23159
# 4           591          40        16632
# ...         ...         ...          ...
# 1465        884          41        12290
# 1466        613          42        21457
# 1467        155          87         5174
# 1468       1023          63        13243
# 1469        628          82        10228
#
# [1470 rows x 3 columns]

# %%
print("Bayaran per hari",df1["DailyRate"][1])
print("Bayaran per bulan",df1["MonthlyRate"][1])
print("ratio=",df1["MonthlyRate"][1]/df1["DailyRate"][1])
# Out:
# Bayaran per hari 279
# Bayaran per bulan 24907
# ratio= 89.27240143369175

# %%
print("Bayaran per hari",df1["DailyRate"][0])
print("Bayaran per bulan",df1["MonthlyRate"][0])
print("ratio=",df1["MonthlyRate"][0]/df1["DailyRate"][0])
# Out:
# Bayaran per hari 1102
# Bayaran per bulan 19479
# ratio= 17.676043557168786

# %%
sns.scatterplot(data=df1, x="DailyRate", y="MonthlyRate")
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='MonthlyRate'>

# %%
sns.scatterplot(data=df1, x="DailyRate", y="HourlyRate")
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='HourlyRate'>

# %%
from string import ascii_letters

sns.set_theme(style="white")

# Compute the correlation matrix
corr = df1.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.5, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df1, x="Age", y="YearsAtCompany")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='YearsAtCompany'>

# %%
sns.scatterplot(data=df1, x="Age", y="JobLevel")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='JobLevel'>

# %%
pearsoncorr = df1.corr(method='pearson')
pearsoncorr
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
fig, ax = plt.subplots(figsize=(20,20)) 
sns.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.9,
           ax=ax)
plt.show()

# %%
sns.scatterplot(data=df1, x="JobLevel", y="MonthlyIncome")
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='MonthlyIncome'>

# %%
ax = sns.boxplot(x="JobLevel", y="MonthlyIncome", data=df1)

# %%
df1[df1['JobLevel']==1]['MonthlyIncome']
# Out:
# 2       2090
# 3       2909
# 4       3468
# 5       3068
# 6       2670
#         ...
# 1455    2809
# 1457    2001
# 1458    2977
# 1460    3785
# 1464    2966
# Name: MonthlyIncome, Length: 543, dtype: int64

# %%
from scipy.stats import f_oneway
alpha=0.05
fstats, pvalue=f_oneway(df1[df1['JobLevel']==1]['MonthlyIncome'],df1[df1['JobLevel']==2]['MonthlyIncome'],df1[df1['JobLevel']==3]['MonthlyIncome'],df1[df1['JobLevel']==4]['MonthlyIncome'],df1[df1['JobLevel']==5]['MonthlyIncome'])

# %%
print(fstats)
print(pvalue)
# Out:
# 4530.221139865191
# 0.0

# %% [markdown]
# ## Kesimpulan: Job Level dan Monthly Income Berkolerasi

# %%
sns.displot(df1, x="NumCompaniesWorked",hue='Attrition')
print(df1['NumCompaniesWorked'].value_counts())
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64

# %%
ax = sns.countplot(x="OverTime", data=df1,hue='Attrition')

# %%
sns.displot(df1, x="PercentSalaryHike",hue='Attrition')

# %%
ax = sns.countplot(x="RelationshipSatisfaction", data=df1,hue='Attrition')

# %%
ax = sns.countplot(x="StockOptionLevel", data=df1,hue='Attrition')

# %%
sns.displot(df1, x="TotalWorkingYears",hue='Attrition')

# %%
ax = sns.countplot(x="TrainingTimesLastYear", data=df1,hue='Attrition')

# %%
ax = sns.countplot(x="WorkLifeBalance", data=df1,hue='Attrition')

# %%
sns.displot(df1, x="YearsAtCompany",hue='Attrition')
plt.show()
print('Satu tahun paling cenderung churn')
# Out:
# Satu tahun paling cenderung churn

# %%
sns.displot(df1, x="YearsInCurrentRole",hue='Attrition')

# %%
sns.displot(df1, x="Age",hue='Attrition')

# %%
sns.displot(df1, x="YearsSinceLastPromotion",hue='Attrition')

# %% [markdown]
# # Mencari NA

# %%
sns.heatmap(df1.isna())
plt.show()

# %%
df = pd.read_csv('train.csv')
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1053   57          0      Travel_Rarely        405  Research & Development
# 1054   49          0      Travel_Rarely       1490  Research & Development
# 1055   34          0  Travel_Frequently        829  Research & Development
# 1056   28          1  Travel_Frequently       1496                   Sales
# 1057   29          1  Travel_Frequently        115                   Sales
#
# ...

# %%
sns.heatmap(df_ibm.isna())
plt.show()

# %%
sns.heatmap(df_ibm_sql.isna())
plt.show()

# %% [markdown]
# # MYsql

# %%
import mysql.connector
import sqlalchemy as db

# %%
engine1=db.create_engine(f'mysql+pymysql://root:120997@localhost:3306/ibm')
con1=engine1.connect()
meta=db.MetaData()

# %%
df_ibm_sql=pd.read_sql("select * from employees;",con1)
df_ibm_sql
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely     1102.0                   Sales
# 1      49        No  Travel_Frequently      279.0  Research & Development
# 2      37       Yes      Travel_Rarely     1373.0  Research & Development
# 3      33        No  Travel_Frequently     1392.0  Research & Development
# 4      27        No      Travel_Rarely      591.0  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently      884.0  Research & Development
# 1466   39        No      Travel_Rarely      613.0  Research & Development
# 1467   27        No      Travel_Rarely      155.0  Research & Development
# 1468   49        No  Travel_Frequently     1023.0                   Sales
# 1469   34        No      Travel_Rarely      628.0  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df_ibm_sql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1177 entries, 0 to 1176
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1177 non-null   int64
#  1   Attrition                 1177 non-null   object
#  2   BusinessTravel            1177 non-null   object
#  3   DailyRate                 1177 non-null   float64
#  4   Department                1177 non-null   object
#  5   DistanceFromHome          1177 non-null   int64
#  6   Education                 1177 non-null   int64
#  7   EducationField            1177 non-null   object
#  8   EmployeeCount             1177 non-null   int64
#  9   EmployeeNumber            1177 non-null   int64
#  10  EnvironmentSatisfaction   1177 non-null   int64
#  11  Gender                    1177 non-null   object
#  12  HourlyRate                1177 non-null   float64
# ...

# %%
df_ibm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1339 non-null   float64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1292 non-null   float64
# ...

# %%
df_ibm_sql['Age'].head(10)
# Out:
# 0    41
# 1    49
# 2    37
# 3    33
# 4    27
# 5    32
# 6    59
# 7    30
# 8    38
# 9    36
# Name: Age, dtype: int64
